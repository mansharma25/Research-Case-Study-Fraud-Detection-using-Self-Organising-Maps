# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import *
import matplotlib.pyplot as plt
dataset = pd.read_csv(r'C:\Manju\Trierdocs\Semester3\CrediCardFraudDetectionApplicationNEW.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
dataset.shape
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
X = sc.fit_transform(X)
modified_sigma=1
sigmas = []
Lrates=[]
efficiency=[]
count=0
for i in range(9): #---- changed to 10 for test 
    modified_learning_rate=0.1
    sigmas.clear()
    efficiency.clear()
    Lrates.clear()
    for j in range(9):
        print("Current learning rate:",modified_learning_rate)
        print("Current sigma:",modified_sigma)
    
        from minisom import MiniSom
        som = MiniSom(x = 10, y = 10, input_len = 16, sigma = modified_sigma, learning_rate = modified_learning_rate)
        som.random_weights_init(X)
        som.train_random(data = X, num_iteration = 100)
        from pylab import bone, pcolor, colorbar
        bone()
        distance_map = som.distance_map().round(1)
        distance_map
        index = []
        for i in range(9):
            for j in range(9): # chnage to 5 from 10
                if(distance_map[i,j]>=0.5):
                    index.append([i,j])
        len(index)
        plt.figure()
        pcolor(som.distance_map().T)
        colorbar() #gives legend
        mappings = som.win_map(X)
        mappings.keys()
        fraud_list = []
        sum = 0
        for x in index:
            fraud_list.append(mappings[(x[0],x[1])])
            sum = sum + len(mappings[(x[0],x[1])])
        sum
        frauds = []
        for x in fraud_list:
            for y in x:
                frauds.append(y)
            
        fraud_array = np.asarray(frauds)
        fraud_inverse_transformed = sc.inverse_transform(frauds) # Undo the scaling of data pattern of frauds according to feature_range
        count = 0
        fraud_id_list = []
        for x in fraud_inverse_transformed:
            fraud_id_list.append(x[0])
        print('Total frauds :{}'.format(len(fraud_id_list)))
        count = 0
        right_prediction_index =[]
        wrong_prediction_index =[]
        for x in fraud_id_list:
            for i,y in enumerate(dataset['CustomerID']):
                if(x == y):
                    if(dataset['Class'][i] == 0):
                        count = count+1
                        right_prediction_index.append(i)
                    else:
                        wrong_prediction_index.append(i)
        a = len(right_prediction_index)
        a
        b=len(wrong_prediction_index)
        b
        l = len(fraud_id_list)
        print('Right Prediction:{}'.format((a/l)*100))
        total_population = dataset.shape[0]
        total_actual_frauds  = dataset[dataset['Class'] == 0].shape[0]
        print('Percentage of frauds detected out of total actual frauds:{}'.format((a/total_actual_frauds)*100))
        print('Percentage of fraud customers in population as claimed by prediction model:{}'.format((a/total_population)*100))
        print('Actual precentage of frauds out of total population:{}'.format((total_actual_frauds/total_population)*100))
        print('Affected population(percentage of custormers who were not fraud but were predicted as fraud)):{}'.format((b/690)*100))
        sigmas.append(modified_sigma)
        Lrates.append(modified_learning_rate)
        efficiency.append((a/total_actual_frauds)*100)
        modified_learning_rate+=0.1     
        print("\n")       
    print("Current Sigma: ",modified_sigma)    
    print("Efficiencies:",efficiency)
    fig=plt.figure()  
    ax = fig.add_subplot(111)
    ax.set_ylim(0,100)
    ax.plot(range(1, len(Lrates) + 1), efficiency)
    start, end = ax.get_xlim()
    ax.set_title('relation between Learning rate and efficiency', fontsize=15)
    ax.set_xlabel('Learning rate x 10', fontsize=12)
    ax.set_ylabel('efficiency', fontsize=12)  
    plt.show()     
    modified_sigma+=1
# Out:
# Current learning rate: 0.1
# Current sigma: 1
# Total frauds :523
# Right Prediction:52.39005736137668
# Percentage of frauds detected out of total actual frauds:71.54046997389034
# Percentage of fraud customers in population as claimed by prediction model:39.710144927536234
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):36.08695652173913
#
#
# Current learning rate: 0.2
# Current sigma: 1
# Total frauds :452
# Right Prediction:51.10619469026548
# Percentage of frauds detected out of total actual frauds:60.313315926892955
# Percentage of fraud customers in population as claimed by prediction model:33.47826086956522
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):32.028985507246375
#
#
# Current learning rate: 0.30000000000000004
# Current sigma: 1
# Total frauds :510
# Right Prediction:53.92156862745098
# Percentage of frauds detected out of total actual frauds:71.80156657963447
# Percentage of fraud customers in population as claimed by prediction model:39.85507246376812
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):34.05797101449276
#
#
# Current learning rate: 0.4
# Current sigma: 1
# Total frauds :502
# Right Prediction:49.800796812749006
# Percentage of frauds detected out of total actual frauds:65.27415143603133
# Percentage of fraud customers in population as claimed by prediction model:36.231884057971016
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):36.52173913043478
#
#
# Current learning rate: 0.5
# Current sigma: 1
# Total frauds :445
# Right Prediction:44.9438202247191
# Percentage of frauds detected out of total actual frauds:52.219321148825074
# Percentage of fraud customers in population as claimed by prediction model:28.985507246376812
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):35.507246376811594
#
#
# Current learning rate: 0.6
# Current sigma: 1
# Total frauds :424
# Right Prediction:59.905660377358494
# Percentage of frauds detected out of total actual frauds:66.31853785900783
# Percentage of fraud customers in population as claimed by prediction model:36.811594202898554
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):24.637681159420293
#
#
# Current learning rate: 0.7
# Current sigma: 1
# Total frauds :471
# Right Prediction:52.653927813163484
# Percentage of frauds detected out of total actual frauds:64.75195822454309
# Percentage of fraud customers in population as claimed by prediction model:35.94202898550725
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):32.31884057971015
#
#
# Current learning rate: 0.7999999999999999
# Current sigma: 1
# Total frauds :425
# Right Prediction:52.470588235294116
# Percentage of frauds detected out of total actual frauds:58.22454308093995
# Percentage of fraud customers in population as claimed by prediction model:32.31884057971015
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):29.275362318840582
#
#
# Current learning rate: 0.8999999999999999
# Current sigma: 1
# Total frauds :387
# Right Prediction:50.90439276485789
# Percentage of frauds detected out of total actual frauds:51.43603133159269
# Percentage of fraud customers in population as claimed by prediction model:28.550724637681157
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):27.536231884057973
#
#
# Current Sigma:  1
# Efficiencies: [71.54046997389034, 60.313315926892955, 71.80156657963447, 65.27415143603133, 52.219321148825074, 66.31853785900783, 64.75195822454309, 58.22454308093995, 51.43603133159269]
# Current learning rate: 0.1
# Current sigma: 2
# Total frauds :497
# Right Prediction:53.923541247484906
# Percentage of frauds detected out of total actual frauds:69.9738903394256
# Percentage of fraud customers in population as claimed by prediction model:38.84057971014493
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):33.18840579710145
#
#
# Current learning rate: 0.2
# Current sigma: 2
# Total frauds :472
# Right Prediction:53.17796610169492
# Percentage of frauds detected out of total actual frauds:65.53524804177546
# Percentage of fraud customers in population as claimed by prediction model:36.3768115942029
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):32.028985507246375
#
#
# Current learning rate: 0.30000000000000004
# Current sigma: 2
# Total frauds :314
# Right Prediction:55.4140127388535
# Percentage of frauds detected out of total actual frauds:45.43080939947781
# Percentage of fraud customers in population as claimed by prediction model:25.217391304347824
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):20.28985507246377
#
#
# Current learning rate: 0.4
# Current sigma: 2
# Total frauds :407
# Right Prediction:58.96805896805897
# Percentage of frauds detected out of total actual frauds:62.66318537859008
# Percentage of fraud customers in population as claimed by prediction model:34.78260869565217
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):24.20289855072464
#
#
# Current learning rate: 0.5
# Current sigma: 2
# Total frauds :341
# Right Prediction:59.530791788856305
# Percentage of frauds detected out of total actual frauds:53.00261096605744
# Percentage of fraud customers in population as claimed by prediction model:29.42028985507246
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):20.0
#
#
# Current learning rate: 0.6
# Current sigma: 2
# Total frauds :390
# Right Prediction:26.410256410256412
# Percentage of frauds detected out of total actual frauds:26.89295039164491
# Percentage of fraud customers in population as claimed by prediction model:14.927536231884059
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):41.594202898550726
#
#
# Current learning rate: 0.7
# Current sigma: 2
# Total frauds :366
# Right Prediction:37.704918032786885
# Percentage of frauds detected out of total actual frauds:36.0313315926893
# Percentage of fraud customers in population as claimed by prediction model:20.0
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):33.04347826086956
#
#
# Current learning rate: 0.7999999999999999
# Current sigma: 2
# Total frauds :336
# Right Prediction:58.333333333333336
# Percentage of frauds detected out of total actual frauds:51.174934725848566
# Percentage of fraud customers in population as claimed by prediction model:28.405797101449277
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):20.28985507246377
#
#
# Current learning rate: 0.8999999999999999
# Current sigma: 2
# Total frauds :389
# Right Prediction:71.46529562982005
# Percentage of frauds detected out of total actual frauds:72.58485639686684
# Percentage of fraud customers in population as claimed by prediction model:40.28985507246377
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):16.08695652173913
#
#
# Current Sigma:  2
# Efficiencies: [69.9738903394256, 65.53524804177546, 45.43080939947781, 62.66318537859008, 53.00261096605744, 26.89295039164491, 36.0313315926893, 51.174934725848566, 72.58485639686684]
# Current learning rate: 0.1
# Current sigma: 3
# Total frauds :489
# Right Prediction:57.668711656441715
# Percentage of frauds detected out of total actual frauds:73.62924281984334
# Percentage of fraud customers in population as claimed by prediction model:40.869565217391305
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):30.0
#
#
# Current learning rate: 0.2
# Current sigma: 3
# Total frauds :302
# Right Prediction:48.675496688741724
# Percentage of frauds detected out of total actual frauds:38.38120104438642
# Percentage of fraud customers in population as claimed by prediction model:21.304347826086957
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):22.463768115942027
#
#
# Current learning rate: 0.30000000000000004
# Current sigma: 3
# Total frauds :235
# Right Prediction:51.91489361702127
# Percentage of frauds detected out of total actual frauds:31.853785900783286
# Percentage of fraud customers in population as claimed by prediction model:17.681159420289855
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):16.3768115942029
#
#
# Current learning rate: 0.4
# Current sigma: 3
# Total frauds :168
# Right Prediction:62.5
# Percentage of frauds detected out of total actual frauds:27.415143603133156
# Percentage of fraud customers in population as claimed by prediction model:15.217391304347828
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):9.130434782608695
#
#
# Current learning rate: 0.5
# Current sigma: 3
# Total frauds :222
# Right Prediction:34.68468468468468
# Percentage of frauds detected out of total actual frauds:20.10443864229765
# Percentage of fraud customers in population as claimed by prediction model:11.159420289855072
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):21.014492753623188
#
#
# Current learning rate: 0.6
# Current sigma: 3
# Total frauds :293
# Right Prediction:58.36177474402731
# Percentage of frauds detected out of total actual frauds:44.64751958224543
# Percentage of fraud customers in population as claimed by prediction model:24.782608695652176
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):17.681159420289855
#
#
# Current learning rate: 0.7
# Current sigma: 3
# Total frauds :297
# Right Prediction:47.81144781144781
# Percentage of frauds detected out of total actual frauds:37.0757180156658
# Percentage of fraud customers in population as claimed by prediction model:20.579710144927535
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):22.463768115942027
#
#
# Current learning rate: 0.7999999999999999
# Current sigma: 3
# Total frauds :246
# Right Prediction:54.87804878048781
# Percentage of frauds detected out of total actual frauds:35.24804177545692
# Percentage of fraud customers in population as claimed by prediction model:19.565217391304348
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):16.08695652173913
#
#
# Current learning rate: 0.8999999999999999
# Current sigma: 3
# Total frauds :294
# Right Prediction:33.33333333333333
# Percentage of frauds detected out of total actual frauds:25.587467362924283
# Percentage of fraud customers in population as claimed by prediction model:14.202898550724639
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):28.405797101449277
#
#
# Current Sigma:  3
# Efficiencies: [73.62924281984334, 38.38120104438642, 31.853785900783286, 27.415143603133156, 20.10443864229765, 44.64751958224543, 37.0757180156658, 35.24804177545692, 25.587467362924283]
# Current learning rate: 0.1
# Current sigma: 4
# Total frauds :410
# Right Prediction:47.80487804878049
# Percentage of frauds detected out of total actual frauds:51.174934725848566
# Percentage of fraud customers in population as claimed by prediction model:28.405797101449277
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):31.01449275362319
#
#
# Current learning rate: 0.2
# Current sigma: 4
# Total frauds :381
# Right Prediction:50.65616797900262
# Percentage of frauds detected out of total actual frauds:50.391644908616186
# Percentage of fraud customers in population as claimed by prediction model:27.97101449275362
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):27.246376811594203
#
#
# Current learning rate: 0.30000000000000004
# Current sigma: 4
# Total frauds :223
# Right Prediction:73.54260089686099
# Percentage of frauds detected out of total actual frauds:42.81984334203655
# Percentage of fraud customers in population as claimed by prediction model:23.768115942028984
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):8.550724637681158
#
#
# Current learning rate: 0.4
# Current sigma: 4
# Total frauds :225
# Right Prediction:66.22222222222223
# Percentage of frauds detected out of total actual frauds:38.90339425587467
# Percentage of fraud customers in population as claimed by prediction model:21.594202898550723
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):11.014492753623188
#
#
# Current learning rate: 0.5
# Current sigma: 4
# Total frauds :143
# Right Prediction:48.95104895104895
# Percentage of frauds detected out of total actual frauds:18.27676240208877
# Percentage of fraud customers in population as claimed by prediction model:10.144927536231885
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):10.579710144927535
#
#
# Current learning rate: 0.6
# Current sigma: 4
# Total frauds :159
# Right Prediction:56.60377358490566
# Percentage of frauds detected out of total actual frauds:23.49869451697128
# Percentage of fraud customers in population as claimed by prediction model:13.043478260869565
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):10.0
#
#
# Current learning rate: 0.7
# Current sigma: 4
# Total frauds :185
# Right Prediction:69.72972972972973
# Percentage of frauds detected out of total actual frauds:33.68146214099217
# Percentage of fraud customers in population as claimed by prediction model:18.695652173913043
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):8.115942028985506
#
#
# Current learning rate: 0.7999999999999999
# Current sigma: 4
# Total frauds :224
# Right Prediction:67.85714285714286
# Percentage of frauds detected out of total actual frauds:39.686684073107045
# Percentage of fraud customers in population as claimed by prediction model:22.028985507246375
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):10.434782608695652
#
#
# Current learning rate: 0.8999999999999999
# Current sigma: 4
# Total frauds :174
# Right Prediction:76.4367816091954
# Percentage of frauds detected out of total actual frauds:34.72584856396867
# Percentage of fraud customers in population as claimed by prediction model:19.275362318840582
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):5.942028985507246
#
#
# Current Sigma:  4
# Efficiencies: [51.174934725848566, 50.391644908616186, 42.81984334203655, 38.90339425587467, 18.27676240208877, 23.49869451697128, 33.68146214099217, 39.686684073107045, 34.72584856396867]
# Current learning rate: 0.1
# Current sigma: 5
# Total frauds :355
# Right Prediction:70.98591549295776
# Percentage of frauds detected out of total actual frauds:65.79634464751958
# Percentage of fraud customers in population as claimed by prediction model:36.52173913043478
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):14.927536231884059
#
#
# Current learning rate: 0.2
# Current sigma: 5
# Total frauds :243
# Right Prediction:94.65020576131687
# Percentage of frauds detected out of total actual frauds:60.052219321148826
# Percentage of fraud customers in population as claimed by prediction model:33.33333333333333
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):1.884057971014493
#
#
# Current learning rate: 0.30000000000000004
# Current sigma: 5
# Total frauds :185
# Right Prediction:55.67567567567567
# Percentage of frauds detected out of total actual frauds:26.89295039164491
# Percentage of fraud customers in population as claimed by prediction model:14.927536231884059
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):11.884057971014492
#
#
# Current learning rate: 0.4
# Current sigma: 5
# Total frauds :209
# Right Prediction:77.03349282296651
# Percentage of frauds detected out of total actual frauds:42.03655352480418
# Percentage of fraud customers in population as claimed by prediction model:23.333333333333332
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):6.956521739130435
#
#
# Current learning rate: 0.5
# Current sigma: 5
# Total frauds :188
# Right Prediction:20.74468085106383
# Percentage of frauds detected out of total actual frauds:10.182767624020887
# Percentage of fraud customers in population as claimed by prediction model:5.6521739130434785
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):21.594202898550723
#
#
# Current learning rate: 0.6
# Current sigma: 5
# Total frauds :118
# Right Prediction:62.71186440677966
# Percentage of frauds detected out of total actual frauds:19.321148825065272
# Percentage of fraud customers in population as claimed by prediction model:10.72463768115942
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):6.3768115942028984
#
#
# Current learning rate: 0.7
# Current sigma: 5
# Total frauds :175
# Right Prediction:48.0
# Percentage of frauds detected out of total actual frauds:21.93211488250653
# Percentage of fraud customers in population as claimed by prediction model:12.173913043478262
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):13.18840579710145
#
#
# Current learning rate: 0.7999999999999999
# Current sigma: 5
# Total frauds :219
# Right Prediction:52.96803652968036
# Percentage of frauds detected out of total actual frauds:30.287206266318538
# Percentage of fraud customers in population as claimed by prediction model:16.81159420289855
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):14.927536231884059
#
#
# Current learning rate: 0.8999999999999999
# Current sigma: 5
# Total frauds :338
# Right Prediction:51.4792899408284
# Percentage of frauds detected out of total actual frauds:45.43080939947781
# Percentage of fraud customers in population as claimed by prediction model:25.217391304347824
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):23.768115942028984
#
#
# Current Sigma:  5
# Efficiencies: [65.79634464751958, 60.052219321148826, 26.89295039164491, 42.03655352480418, 10.182767624020887, 19.321148825065272, 21.93211488250653, 30.287206266318538, 45.43080939947781]
# Current learning rate: 0.1
# Current sigma: 6
# Total frauds :364
# Right Prediction:52.472527472527474
# Percentage of frauds detected out of total actual frauds:49.869451697127936
# Percentage of fraud customers in population as claimed by prediction model:27.681159420289852
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):25.072463768115945
#
#
# Current learning rate: 0.2
# Current sigma: 6
# Total frauds :153
# Right Prediction:73.20261437908496
# Percentage of frauds detected out of total actual frauds:29.242819843342037
# Percentage of fraud customers in population as claimed by prediction model:16.231884057971012
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):5.942028985507246
#
#
# Current learning rate: 0.30000000000000004
# Current sigma: 6
# Total frauds :294
# Right Prediction:75.17006802721087
# Percentage of frauds detected out of total actual frauds:57.702349869451695
# Percentage of fraud customers in population as claimed by prediction model:32.028985507246375
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):10.579710144927535
#
#
# Current learning rate: 0.4
# Current sigma: 6
# Total frauds :161
# Right Prediction:35.40372670807454
# Percentage of frauds detected out of total actual frauds:14.882506527415144
# Percentage of fraud customers in population as claimed by prediction model:8.26086956521739
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):15.072463768115943
#
#
# Current learning rate: 0.5
# Current sigma: 6
# Total frauds :153
# Right Prediction:64.70588235294117
# Percentage of frauds detected out of total actual frauds:25.848563968668408
# Percentage of fraud customers in population as claimed by prediction model:14.347826086956522
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):7.82608695652174
#
#
# Current learning rate: 0.6
# Current sigma: 6
# Total frauds :151
# Right Prediction:77.48344370860927
# Percentage of frauds detected out of total actual frauds:30.548302872062667
# Percentage of fraud customers in population as claimed by prediction model:16.956521739130434
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):4.9275362318840585
#
#
# Current learning rate: 0.7
# Current sigma: 6
# Total frauds :128
# Right Prediction:21.875
# Percentage of frauds detected out of total actual frauds:7.310704960835509
# Percentage of fraud customers in population as claimed by prediction model:4.057971014492753
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):14.492753623188406
#
#
# Current learning rate: 0.7999999999999999
# Current sigma: 6
# Total frauds :222
# Right Prediction:64.86486486486487
# Percentage of frauds detected out of total actual frauds:37.59791122715404
# Percentage of fraud customers in population as claimed by prediction model:20.869565217391305
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):11.304347826086957
#
#
# Current learning rate: 0.8999999999999999
# Current sigma: 6
# Total frauds :297
# Right Prediction:46.12794612794613
# Percentage of frauds detected out of total actual frauds:35.77023498694517
# Percentage of fraud customers in population as claimed by prediction model:19.855072463768117
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):23.18840579710145
#
#
# Current Sigma:  6
# Efficiencies: [49.869451697127936, 29.242819843342037, 57.702349869451695, 14.882506527415144, 25.848563968668408, 30.548302872062667, 7.310704960835509, 37.59791122715404, 35.77023498694517]
# Current learning rate: 0.1
# Current sigma: 7
# Total frauds :253
# Right Prediction:67.98418972332016
# Percentage of frauds detected out of total actual frauds:44.90861618798956
# Percentage of fraud customers in population as claimed by prediction model:24.92753623188406
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):11.73913043478261
#
#
# Current learning rate: 0.2
# Current sigma: 7
# Total frauds :171
# Right Prediction:45.02923976608187
# Percentage of frauds detected out of total actual frauds:20.10443864229765
# Percentage of fraud customers in population as claimed by prediction model:11.159420289855072
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):13.623188405797102
#
#
# Current learning rate: 0.30000000000000004
# Current sigma: 7
# Total frauds :139
# Right Prediction:45.32374100719424
# Percentage of frauds detected out of total actual frauds:16.449086161879894
# Percentage of fraud customers in population as claimed by prediction model:9.130434782608695
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):11.014492753623188
#
#
# Current learning rate: 0.4
# Current sigma: 7
# Total frauds :122
# Right Prediction:69.67213114754098
# Percentage of frauds detected out of total actual frauds:22.193211488250654
# Percentage of fraud customers in population as claimed by prediction model:12.318840579710146
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):5.36231884057971
#
#
# Current learning rate: 0.5
# Current sigma: 7
# Total frauds :160
# Right Prediction:33.125
# Percentage of frauds detected out of total actual frauds:13.838120104438643
# Percentage of fraud customers in population as claimed by prediction model:7.681159420289855
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):15.507246376811596
#
#
# Current learning rate: 0.6
# Current sigma: 7
# Total frauds :84
# Right Prediction:54.761904761904766
# Percentage of frauds detected out of total actual frauds:12.010443864229766
# Percentage of fraud customers in population as claimed by prediction model:6.666666666666667
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):5.507246376811594
#
#
# Current learning rate: 0.7
# Current sigma: 7
# Total frauds :133
# Right Prediction:60.902255639097746
# Percentage of frauds detected out of total actual frauds:21.148825065274153
# Percentage of fraud customers in population as claimed by prediction model:11.73913043478261
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):7.536231884057972
#
#
# Current learning rate: 0.7999999999999999
# Current sigma: 7
# Total frauds :126
# Right Prediction:16.666666666666664
# Percentage of frauds detected out of total actual frauds:5.483028720626632
# Percentage of fraud customers in population as claimed by prediction model:3.0434782608695654
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):15.217391304347828
#
#
# Current learning rate: 0.8999999999999999
# Current sigma: 7
# Total frauds :265
# Right Prediction:38.113207547169814
# Percentage of frauds detected out of total actual frauds:26.370757180156655
# Percentage of fraud customers in population as claimed by prediction model:14.637681159420291
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):23.768115942028984
#
#
# Current Sigma:  7
# Efficiencies: [44.90861618798956, 20.10443864229765, 16.449086161879894, 22.193211488250654, 13.838120104438643, 12.010443864229766, 21.148825065274153, 5.483028720626632, 26.370757180156655]
# Current learning rate: 0.1
# Current sigma: 8
# Total frauds :243
# Right Prediction:74.8971193415638
# Percentage of frauds detected out of total actual frauds:47.51958224543081
# Percentage of fraud customers in population as claimed by prediction model:26.3768115942029
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):8.840579710144928
#
#
# Current learning rate: 0.2
# Current sigma: 8
# Total frauds :65
# Right Prediction:38.46153846153847
# Percentage of frauds detected out of total actual frauds:6.527415143603134
# Percentage of fraud customers in population as claimed by prediction model:3.6231884057971016
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):5.797101449275362
#
#
# Current learning rate: 0.30000000000000004
# Current sigma: 8
# Total frauds :112
# Right Prediction:41.07142857142857
# Percentage of frauds detected out of total actual frauds:12.010443864229766
# Percentage of fraud customers in population as claimed by prediction model:6.666666666666667
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):9.565217391304348
#
#
# Current learning rate: 0.4
# Current sigma: 8
# Total frauds :124
# Right Prediction:67.74193548387096
# Percentage of frauds detected out of total actual frauds:21.93211488250653
# Percentage of fraud customers in population as claimed by prediction model:12.173913043478262
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):5.797101449275362
#
#
# Current learning rate: 0.5
# Current sigma: 8
# Total frauds :67
# Right Prediction:56.71641791044776
# Percentage of frauds detected out of total actual frauds:9.921671018276761
# Percentage of fraud customers in population as claimed by prediction model:5.507246376811594
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):4.202898550724638
#
#
# Current learning rate: 0.6
# Current sigma: 8
# Total frauds :141
# Right Prediction:21.98581560283688
# Percentage of frauds detected out of total actual frauds:8.093994778067886
# Percentage of fraud customers in population as claimed by prediction model:4.492753623188406
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):15.942028985507244
#
#
# Current learning rate: 0.7
# Current sigma: 8
# Total frauds :121
# Right Prediction:53.71900826446281
# Percentage of frauds detected out of total actual frauds:16.971279373368144
# Percentage of fraud customers in population as claimed by prediction model:9.420289855072465
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):8.115942028985506
#
#
# Current learning rate: 0.7999999999999999
# Current sigma: 8
# Total frauds :172
# Right Prediction:56.97674418604651
# Percentage of frauds detected out of total actual frauds:25.587467362924283
# Percentage of fraud customers in population as claimed by prediction model:14.202898550724639
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):10.72463768115942
#
#
# Current learning rate: 0.8999999999999999
# Current sigma: 8
# Total frauds :176
# Right Prediction:48.29545454545455
# Percentage of frauds detected out of total actual frauds:22.193211488250654
# Percentage of fraud customers in population as claimed by prediction model:12.318840579710146
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):13.18840579710145
#
#
# Current Sigma:  8
# Efficiencies: [47.51958224543081, 6.527415143603134, 12.010443864229766, 21.93211488250653, 9.921671018276761, 8.093994778067886, 16.971279373368144, 25.587467362924283, 22.193211488250654]
# Current learning rate: 0.1
# Current sigma: 9
# Total frauds :337
# Right Prediction:31.750741839762615
# Percentage of frauds detected out of total actual frauds:27.93733681462141
# Percentage of fraud customers in population as claimed by prediction model:15.507246376811596
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):33.33333333333333
#
#
# Current learning rate: 0.2
# Current sigma: 9
# Total frauds :123
# Right Prediction:38.21138211382114
# Percentage of frauds detected out of total actual frauds:12.27154046997389
# Percentage of fraud customers in population as claimed by prediction model:6.811594202898551
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):11.014492753623188
#
#
# Current learning rate: 0.30000000000000004
# Current sigma: 9
# Total frauds :79
# Right Prediction:91.13924050632912
# Percentage of frauds detected out of total actual frauds:18.79895561357702
# Percentage of fraud customers in population as claimed by prediction model:10.434782608695652
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):1.0144927536231882
#
#
# Current learning rate: 0.4
# Current sigma: 9
# Total frauds :134
# Right Prediction:50.74626865671642
# Percentage of frauds detected out of total actual frauds:17.75456919060052
# Percentage of fraud customers in population as claimed by prediction model:9.855072463768117
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):9.565217391304348
#
#
# Current learning rate: 0.5
# Current sigma: 9
# Total frauds :134
# Right Prediction:92.53731343283582
# Percentage of frauds detected out of total actual frauds:32.375979112271544
# Percentage of fraud customers in population as claimed by prediction model:17.971014492753625
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):1.4492753623188406
#
#
# Current learning rate: 0.6
# Current sigma: 9
# Total frauds :105
# Right Prediction:64.76190476190476
# Percentage of frauds detected out of total actual frauds:17.75456919060052
# Percentage of fraud customers in population as claimed by prediction model:9.855072463768117
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):5.36231884057971
#
#
# Current learning rate: 0.7
# Current sigma: 9
# Total frauds :180
# Right Prediction:85.55555555555556
# Percentage of frauds detected out of total actual frauds:40.2088772845953
# Percentage of fraud customers in population as claimed by prediction model:22.318840579710145
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):3.768115942028986
#
#
# Current learning rate: 0.7999999999999999
# Current sigma: 9
# Total frauds :140
# Right Prediction:78.57142857142857
# Percentage of frauds detected out of total actual frauds:28.720626631853786
# Percentage of fraud customers in population as claimed by prediction model:15.942028985507244
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):4.3478260869565215
#
#
# Current learning rate: 0.8999999999999999
# Current sigma: 9
# Total frauds :252
# Right Prediction:40.07936507936508
# Percentage of frauds detected out of total actual frauds:26.370757180156655
# Percentage of fraud customers in population as claimed by prediction model:14.637681159420291
# Actual precentage of frauds out of total population:55.507246376811594
# Affected population(percentage of custormers who were not fraud but were predicted as fraud)):21.884057971014492
#
#
# Current Sigma:  9
# Efficiencies: [27.93733681462141, 12.27154046997389, 18.79895561357702, 17.75456919060052, 32.375979112271544, 17.75456919060052, 40.2088772845953, 28.720626631853786, 26.370757180156655]
